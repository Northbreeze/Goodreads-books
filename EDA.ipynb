# %%
import pandas as pd

# %%
df=pd.read_csv ('books.csv')

# %%
df.head(5)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3       4  Harry Potter and the Chamber of Secrets (Harry...
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...
#
#                       authors average_rating        isbn       isbn13  \
# 0  J.K. Rowling-Mary GrandPré           4.56   439785960  9.78044E+12
# 1  J.K. Rowling-Mary GrandPré           4.49   439358078  9.78044E+12
# 2  J.K. Rowling-Mary GrandPré           4.47   439554934  9.78044E+12
# 3                J.K. Rowling           4.41   439554896  9.78044E+12
# 4  J.K. Rowling-Mary GrandPré           4.55  043965548X  9.78044E+12
#
#   language_code # num_pages  ratings_count  text_reviews_count  Unnamed: 10
# 0           eng         652        1944099               26249          NaN
# ...

# %%
df['authors'].value_counts().head(10)
# Out:
# Agatha Christie                69
# Stephen King                   66
# Orson Scott Card               48
# Rumiko Takahashi               46
# P.G. Wodehouse                 42
# Terry Brooks                   40
# Piers Anthony                  34
# Margaret Weis-Tracy Hickman    33
# Dan Simmons                    32
# Gabriel García Márquez         31
# Name: authors, dtype: int64

# %%
df[df['authors']=='Agatha Christie']
# Out:
#        bookID                                              title  \
# 5442    16297           Cards on the Table (Hercule Poirot  #15)
# 5443    16298            A Murder Is Announced (Miss Marple  #5)
# 5444    16299                           And Then There Were None
# 5445    16300                  Sleeping Murder (Miss Marple #13)
# 5447    16303                   The Hollow (Hercule Poirot  #26)
# 5448    16304  Murder on the Orient Express (Hercule Poirot  ...
# 5449    16305           Evil Under the Sun (Hercule Poirot  #24)
# 5450    16306  Miss Marple: The Complete Short Stories (Miss ...
# 5451    16307             Hallowe'en Party (Hercule Poirot  #39)
# 5452    16308           Taken at the Flood (Hercule Poirot  #28)
# 5455    16314             4.50 From Paddington (Miss Marple  #8)
# 5456    16315                                      Crooked House
# 5457    16316                  The Big Four (Hercule Poirot  #5)
# ...

# %% [markdown]
# ## # select top 10 rating books

# %%
df[df['text_reviews_count']>20].sort_values('average_rating',ascending=False).head(10)
# Out:
#        bookID                                              title  \
# 7925    24812                     The Complete Calvin and Hobbes
# 5           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 7927    24814       It's a Magical World (Calvin and Hobbes #11)
# 7928    24815                The Indispensable Calvin and Hobbes
# 7          10       Harry Potter Collection (Harry Potter  #1-6)
# 7929    24816  Homicidal Psycho Jungle Cat (Calvin and Hobbes...
# 7933    24820  Calvin and Hobbes: Sunday Pages 1985-1995: An ...
# 12981   44826  The Price of the Ticket: Collected Nonfiction ...
# 4406    13358  The Everyday Life Bible: The Power of God's Wo...
# 6755    20749                                   Study Bible: NIV
#
#                           authors average_rating       isbn       isbn13  \
# 7925               Bill Watterson           4.82  740748475  9.78074E+12
# 5      J.K. Rowling-Mary GrandPré           4.78  439682584  9.78044E+12
# ...
